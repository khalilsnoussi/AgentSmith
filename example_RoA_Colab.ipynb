# %% [markdown]
# <a href="https://colab.research.google.com/github/khalilsnoussi/AgentSmith/blob/main/example_RoA_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Executing a Rain over Africa retrieval
#
# In this notebook I will walk you through finding, downloading, executing, and saving a Rain over Africa (RoA) retrieval, using a free Google Colab GPU runtime and the latest Meteosat Second Generation image.
#
# First, we select the GPU runtime. At the time of writing, this is "T4 GPU".
#
# Note that the code in this notebook is adapted to the limits of this runtime, shown below:

# %%
# %%bash
# echo "Today is `date`"
# echo
# lscpu | grep -E 'Model name|^CPU\(s\):|MHz' | awk '{$1=$1; print}'
# echo
# echo "System memory:"
# awk '/MemTotal/ {printf "%.2f GiB\n", $2 / 1024 / 1024}' /proc/meminfo
# echo
# echo "GPU:"
# nvidia-smi --query-gpu=gpu_name,memory.total --format=csv,noheader
# echo
# echo "Python version: `python --version`"
# Out:
# Today is Thu Mar  5 10:18:58 PM UTC 2026
#
# CPU(s): 2
# Model name: Intel(R) Xeon(R) CPU @ 2.00GHz
#
# System memory:
# 12.67 GiB
#
# GPU:
# Tesla T4, 15360 MiB
#
# Python version: Python 3.12.12

# %% [markdown]
# but if you want to run using other system resources, i.e. a small GPU and more RAM, it is likely doable.

# %% [markdown]
# We begin by setting up the Google Colab environment:

# %%
# %%bash
# pip install -U pip setuptools wheel build
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (26.0.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (82.0.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (0.46.3)
# Requirement already satisfied: build in /usr/local/lib/python3.12/dist-packages (1.4.0)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from wheel) (26.0)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.12/dist-packages (from build) (1.2.0)

# %%
# !rm -rf satrain*
# !wget https://codeload.github.com/ipwgml/satrain/zip/refs/heads/main -O satrain.zip
# !unzip satrain.zip
# Out:
# --2026-03-05 22:19:00--  https://codeload.github.com/ipwgml/satrain/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 20.205.243.165
# Connecting to codeload.github.com (codeload.github.com)|20.205.243.165|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘satrain.zip’
#
# satrain.zip             [          <=>       ]  28.51M  10.3MB/s    in 2.8s
#
# 2026-03-05 22:19:03 (10.3 MB/s) - ‘satrain.zip’ saved [29893065]
#
# Archive:  satrain.zip
# 8d91e592b2276466563ebb9731a01936d837108e
#    creating: satrain-main/
#    creating: satrain-main/.github/
#    creating: satrain-main/.github/workflows/
#   inflating: satrain-main/.github/workflows/install_and_test.yml
#   inflating: satrain-main/.github/workflows/release.yml
#   inflating: satrain-main/.readthedocs.yaml
#   inflating: satrain-main/LICENSE.txt
#   inflating: satrain-main/MANIFEST.in
#   inflating: satrain-main/README.md
#   inflating: satrain-main/conda_environment.yml
#    creating: satrain-main/docs/
#   inflating: satrain-main/docs/_config.yml
#   inflating: satrain-main/docs/_toc.yml
#    creating: satrain-main/docs/api/
#   inflating: satrain-main/docs/api/baselines.rst
#   inflating: satrain-main/docs/api/cli.rst
#   inflating: satrain-main/docs/api/config.rst
#   inflating: satrain-main/docs/api/data.rst
#  extracting: satrain-main/docs/api/evaluation.rst
#  extracting: satrain-main/docs/api/input.rst
#   inflating: satrain-main/docs/api/logging.rst
#  extracting: satrain-main/docs/api/metrics.rst
#   inflating: satrain-main/docs/api/plotting.rst
#    creating: satrain-main/docs/api/pytorch/
#   inflating: satrain-main/docs/api/pytorch/datasets.rst
#  extracting: satrain-main/docs/api/pytorch/pytorch.rst
#  extracting: satrain-main/docs/api/target.rst
#   inflating: satrain-main/docs/api/tiling.rst
#   inflating: satrain-main/docs/api/utils.rst
#   inflating: satrain-main/docs/api_documentation.md
#   inflating: satrain-main/docs/dataset.md
#   inflating: satrain-main/docs/examples.md
#    creating: satrain-main/docs/figures/
#   inflating: satrain-main/docs/figures/evaluation.svg
#   inflating: satrain-main/docs/figures/example_scene.png
#   inflating: satrain-main/docs/figures/processing.svg
#   inflating: satrain-main/docs/figures/retrieval_example.png
#   inflating: satrain-main/docs/getting_started.ipynb
#   inflating: satrain-main/docs/intro.md
#    creating: satrain-main/docs/notebooks/
#   inflating: satrain-main/docs/notebooks/evaluate_gprof.ipynb
#   inflating: satrain-main/docs/notebooks/evaluate_imerg.ipynb
#   inflating: satrain-main/docs/notebooks/input_and_target_data.ipynb
#    creating: satrain-main/docs/notebooks/pytorch/
#   inflating: satrain-main/docs/notebooks/pytorch/convolutional_neural_network.ipynb
#   inflating: satrain-main/docs/notebooks/pytorch/fully_connected.ipynb
#   inflating: satrain-main/docs/notebooks/testing.ipynb
#    creating: satrain-main/models/
#    creating: satrain-main/models/satrain/
#    creating: satrain-main/models/satrain/geo/
#  extracting: satrain-main/models/satrain/geo/compute.toml
#   inflating: satrain-main/models/satrain/geo/model.toml
#   inflating: satrain-main/models/satrain/geo/training.toml
#    creating: satrain-main/models/satrain/geo_ir/
#  extracting: satrain-main/models/satrain/geo_ir/compute.toml
#   inflating: satrain-main/models/satrain/geo_ir/model.toml
#   inflating: satrain-main/models/satrain/geo_ir/training.toml
#    creating: satrain-main/models/satrain/gmi/
#  extracting: satrain-main/models/satrain/gmi/compute.toml
#   inflating: satrain-main/models/satrain/gmi/model.toml
#   inflating: satrain-main/models/satrain/gmi/training.toml
#    creating: satrain-main/notebooks/
#    creating: satrain-main/notebooks/pytorch/
#   inflating: satrain-main/notebooks/pytorch/fully_connected.ipynb
#   inflating: satrain-main/pyproject.toml
#    creating: satrain-main/src/
#    creating: satrain-main/src/satrain/
#   inflating: satrain-main/src/satrain/__init__.py
#   inflating: satrain-main/src/satrain/baselines.py
#   inflating: satrain-main/src/satrain/cli.py
#   inflating: satrain-main/src/satrain/config.py
#   inflating: satrain-main/src/satrain/data.py
#   inflating: satrain-main/src/satrain/definitions.py
#   inflating: satrain-main/src/satrain/evaluation.py
#    creating: satrain-main/src/satrain/files/
#    creating: satrain-main/src/satrain/files/baselines/
#   inflating: satrain-main/src/satrain/files/baselines/era5_atms_austria.nc
#   inflating: satrain-main/src/satrain/files/baselines/era5_atms_conus.nc
#   inflating: satrain-main/src/satrain/files/baselines/era5_atms_korea.nc
#   inflating: satrain-main/src/satrain/files/baselines/era5_gmi_austria.nc
#   inflating: satrain-main/src/satrain/files/baselines/era5_gmi_conus.nc
#   inflating: satrain-main/src/satrain/files/baselines/era5_gmi_korea.nc
#   inflating: satrain-main/src/satrain/files/baselines/gprof_v07_atms_austria.nc
#   inflating: satrain-main/src/satrain/files/baselines/gprof_v07_atms_conus.nc
#   inflating: satrain-main/src/satrain/files/baselines/gprof_v07_atms_korea.nc
#   inflating: satrain-main/src/satrain/files/baselines/gprof_v07_gmi_austria.nc
#   inflating: satrain-main/src/satrain/files/baselines/gprof_v07_gmi_conus.nc
#   inflating: satrain-main/src/satrain/files/baselines/gprof_v07_gmi_korea.nc
#   inflating: satrain-main/src/satrain/files/files_satrain.json.gz
#  extracting: satrain-main/src/satrain/files/files_satrain_test.json.gz
#   inflating: satrain-main/src/satrain/files/satrain.mplstyle
#    creating: satrain-main/src/satrain/files/stats/
#   inflating: satrain-main/src/satrain/files/stats/ancillary.nc
#   inflating: satrain-main/src/satrain/files/stats/eia_atms.nc
#   inflating: satrain-main/src/satrain/files/stats/eia_gmi.nc
#   inflating: satrain-main/src/satrain/files/stats/obs_atms.nc
#   inflating: satrain-main/src/satrain/files/stats/obs_geo.nc
#   inflating: satrain-main/src/satrain/files/stats/obs_geo_ir.nc
#   inflating: satrain-main/src/satrain/files/stats/obs_gmi.nc
#   inflating: satrain-main/src/satrain/input.py
#   inflating: satrain-main/src/satrain/logging.py
#   inflating: satrain-main/src/satrain/metrics.py
#   inflating: satrain-main/src/satrain/plotting.py
#    creating: satrain-main/src/satrain/pytorch/
#   inflating: satrain-main/src/satrain/pytorch/__init__.py
#   inflating: satrain-main/src/satrain/pytorch/datasets.py
#   inflating: satrain-main/src/satrain/target.py
#   inflating: satrain-main/src/satrain/tiling.py
#   inflating: satrain-main/src/satrain/utils.py
#    creating: satrain-main/tests/
#   inflating: satrain-main/tests/conftest.py
#    creating: satrain-main/tests/pytorch/
#   inflating: satrain-main/tests/pytorch/test_datasets.py
#   inflating: satrain-main/tests/pytorch/test_pytorch.py
#   inflating: satrain-main/tests/test_baselines.py
#   inflating: satrain-main/tests/test_config.py
#   inflating: satrain-main/tests/test_data.py
#   inflating: satrain-main/tests/test_evaluation.py
#   inflating: satrain-main/tests/test_input.py
#   inflating: satrain-main/tests/test_metrics.py
#   inflating: satrain-main/tests/test_target.py
#   inflating: satrain-main/tests/test_tiling.py
#   inflating: satrain-main/tests/test_utils.py

# %%
pip install --no-build-isolation ./satrain-main
# Out:
# Processing ./satrain-main
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: appdirs in /usr/local/lib/python3.12/dist-packages (from satrain==0.0.0) (1.4.4)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from satrain==0.0.0) (8.3.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from satrain==0.0.0) (7.7.1)
# Collecting numpy<2 (from satrain==0.0.0)
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: netCDF4<1.7 in /usr/local/lib/python3.12/dist-packages (from satrain==0.0.0) (1.6.5)
# Requirement already satisfied: h5netcdf in /usr/local/lib/python3.12/dist-packages (from satrain==0.0.0) (1.8.1)
# Requirement already satisfied: hdf5plugin in /usr/local/lib/python3.12/dist-packages (from satrain==0.0.0) (6.0.0)
# Requirement already satisfied: jupyter-book in /usr/local/lib/python3.12/dist-packages (from satrain==0.0.0) (2.1.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from satrain==0.0.0) (3.10.0)
# Requirement already satisfied: requests-cache in /usr/local/lib/python3.12/dist-packages (from satrain==0.0.0) (1.3.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from satrain==0.0.0) (13.9.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from satrain==0.0.0) (1.16.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from satrain==0.0.0) (0.13.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.12/dist-packages (from satrain==0.0.0) (0.10.2)
# Requirement already satisfied: xarray in /usr/local/lib/python3.12/dist-packages (from satrain==0.0.0) (2025.12.0)
# Requirement already satisfied: cftime in /usr/local/lib/python3.12/dist-packages (from netCDF4<1.7->satrain==0.0.0) (1.6.5)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from netCDF4<1.7->satrain==0.0.0) (2026.2.25)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from h5netcdf->satrain==0.0.0) (26.0)
# Requirement already satisfied: h5py>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from hdf5plugin->satrain==0.0.0) (3.15.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->satrain==0.0.0) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->satrain==0.0.0) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->satrain==0.0.0) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->satrain==0.0.0) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->satrain==0.0.0) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->satrain==0.0.0) (3.0.16)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (6.5.7)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->satrain==0.0.0) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->satrain==0.0.0) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->satrain==0.0.0) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->satrain==0.0.0) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->satrain==0.0.0) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->satrain==0.0.0) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->satrain==0.0.0) (6.5.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->satrain==0.0.0) (82.0.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->satrain==0.0.0) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->satrain==0.0.0) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->satrain==0.0.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->satrain==0.0.0) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->satrain==0.0.0) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->satrain==0.0.0) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->satrain==0.0.0) (4.9.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->satrain==0.0.0) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->satrain==0.0.0) (0.8.6)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->satrain==0.0.0) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->satrain==0.0.0) (5.9.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->satrain==0.0.0) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->satrain==0.0.0) (4.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (3.1.6)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (7.17.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (0.24.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (1.3.3)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (1.5.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (4.26.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (0.30.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.12/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (2.14.0)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (4.12.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (0.5.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (1.9.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (3.11)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (4.15.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (25.1.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (25.10.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->satrain==0.0.0) (0.7.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->satrain==0.0.0) (1.17.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (2.8.3)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (1.4.0)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.12/dist-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->satrain==0.0.0) (2025.3)
# Requirement already satisfied: nodeenv>=1.9.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-book->satrain==0.0.0) (1.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->satrain==0.0.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->satrain==0.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->satrain==0.0.0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->satrain==0.0.0) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->satrain==0.0.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->satrain==0.0.0) (3.3.2)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache->satrain==0.0.0) (26.1.0)
# Requirement already satisfied: requests>=2.22 in /usr/local/lib/python3.12/dist-packages (from requests-cache->satrain==0.0.0) (2.32.4)
# Requirement already satisfied: url-normalize>=2.0 in /usr/local/lib/python3.12/dist-packages (from requests-cache->satrain==0.0.0) (2.2.1)
# Requirement already satisfied: urllib3>=1.25.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache->satrain==0.0.0) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.22->requests-cache->satrain==0.0.0) (3.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->satrain==0.0.0) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->satrain==0.0.0) (0.1.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from seaborn->satrain==0.0.0) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn->satrain==0.0.0) (2025.2)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# Building wheels for collected packages: satrain
#   Building wheel for satrain (pyproject.toml) ... done
#   Created wheel for satrain: filename=satrain-0.0.0-py3-none-any.whl size=22926421 sha256=3a2fcbfc3c9fb6733e174196635f4702fed484340afb6eb948cfcb2544d8a527
#   Stored in directory: /root/.cache/pip/wheels/6e/39/f8/0c6349eb564ff333b2ef69e5daf6a0a42d16783b96ef6cb267
# Successfully built satrain
# Installing collected packages: numpy, satrain
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.0
#     Uninstalling numpy-2.1.0:
#       Successfully uninstalled numpy-2.1.0
#   Attempting uninstall: satrain
#     Found existing installation: satrain 0.0.0
#     Uninstalling satrain-0.0.0:
#       Successfully uninstalled satrain-0.0.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [satrain]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# satpy 0.60.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4 satrain-0.0.0

# %%
# !wget https://codeload.github.com/SEE-GEO/roa/zip/refs/heads/main -O roa.zip
# !unzip roa.zip
# Out:
# --2026-03-05 22:19:21--  https://codeload.github.com/SEE-GEO/roa/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 20.205.243.165
# Connecting to codeload.github.com (codeload.github.com)|20.205.243.165|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘roa.zip’
#
# roa.zip                 [  <=>               ]   4.90M  21.2MB/s    in 0.2s
#
# 2026-03-05 22:19:22 (21.2 MB/s) - ‘roa.zip’ saved [5137076]
#
# Archive:  roa.zip
# ae9b4148ca29ca0730fd3b4d1098e6a5f3787e59
# replace roa-main/.gitignore? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
from pathlib import Path

p = Path("/content/roa-main/pyproject.toml")
txt = p.read_text()

# remove the vcs versioning block
txt = txt.replace('[tool.hatch.version]\nsource = "vcs"', "")

# also ensure version exists
txt = txt.replace("dynamic = [\"version\"]", 'version = "0.0.0"')

p.write_text(txt)

print("pyproject patched")
# Out:
# pyproject patched

# %%
# !pip install -e /content/roa-main --no-deps
# Out:
# Obtaining file:///content/roa-main

# %%
pip install numpy==2.1.0 cmocean eumdac quantnn matplotlib array-api-compat pansat==0.1.2 pyresample satpy zarr

# %%
# Import libraries
import datetime
import getpass
import hashlib
from pathlib import Path
import shutil
import sys
import time

import cmocean
import eumdac
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import quantnn
import torch
import tqdm
import xarray as xr

# RoA library
from roa import (
    MSGNative,
    QUANTILES,
    prepare_dataset_for_network,
    Tiler
)
from roa.data import SEVIRI_0DEG_AREADEF

print(f"Python version {sys.version}\n")
for module in [eumdac, matplotlib, np, torch, xr]:
    print(f"{module.__name__}: {module.__version__}")

# %% [markdown]
# `roa` is at commit

# %%
# !git ls-remote https://github.com/SEE-GEO/roa.git HEAD

# %% [markdown]
# Let's say we want to run a retrieval for the latest Meteosat Second Generation scan. We search for the latest 15 minutes in UTC:

# %%
dtend = datetime.datetime.now(datetime.UTC)
dtstart = dtend - datetime.timedelta(minutes=15)

# %% [markdown]
# and use eumdac to search for the file (you need [EUMETSAT Data Store authentication](https://user.eumetsat.int/resources/user-guides/data-store-detailed-guide#ID-Authentication)):

# %%
# Get access to EUMETSAT Data Store
token = eumdac.AccessToken(
    (
        getpass.getpass("EUMETSAT Consumer key: "),
        getpass.getpass("EUMETSAT Consumer secret: ")
    )
)
datastore = eumdac.DataStore(token)
selected_collection = datastore.get_collection('EO:EUM:DAT:MSG:HRSEVIRI')

nat_files = [f for f in list(selected_collection.search(dtstart=dtstart, dtend=dtend))]

# %% [markdown]
# The variable `nat_files` contains all MSG observations at 0 degree in the last 15 minutes, which we expect to be 1

# %%
assert len(nat_files) == 1

# %% [markdown]
# We will download the file and execute the retrieval on it.
#
# But first, we download the RoA network:

# %%
# !wget -O /content/network_CPU.pt https://raw.githubusercontent.com/SEE-GEO/roa/refs/heads/main/data/network_CPU.pt

with open('/content/network_CPU.pt', 'rb') as handle:
  assert hashlib.md5(handle.read()).hexdigest() == r"135d57c80d10417ce98578d9a1f7d5dd"

# %%
# Load model on the GPU
model_gpu = torch.jit.load(
    '/content/network_CPU.pt',
    map_location=torch.device('cuda')
)

# %%
# Working path
opath = Path('/content/tmp')
opath.mkdir(exist_ok=True)

# For measuring times
times = dict()

# %%
# Download the file
t = time.time()
p = nat_files[0]
entry = f'{str(p)}.nat'
with p.open(entry=entry) as fsrc:
    with open(opath / entry, 'wb') as fdst:
        shutil.copyfileobj(fsrc, fdst)
times['download'] = time.time() - t

# %%
# Read data
t = time.time()
ds = MSGNative(opath / entry).get_dataset().load()
ds = ds.assign_coords({"nat_file": entry}).expand_dims("nat_file")
times['read'] = time.time() - t

# %%
# Prepare the dataset for the network
t = time.time()
x = prepare_dataset_for_network(ds.sel(nat_file=entry))[None, ...]
tiler = Tiler(x)

# Get tiles and put them in the batch dimension
x = torch.stack(
        [tiler.get_tile(i,j) for i in range(tiler.M) for j in range(tiler.N)],
        dim=0
    )
x = x.view(-1, *x.shape[2:])
times['preprocess'] = time.time() - t

# %%
# Run inference in GPU
t = time.time()

# Note: three options, depending on the GPU and system memory available:
# (a) Run the whole batch at once (GPU expensive)
#   y_hat = model_gpu(x.cuda()))
# (b) Run in batches and add the results to a preallocated tensor in GPU
#   (less GPU expensive)
# (c) Run in batches and add the results to a preallocated tensor in CPU
#   (even less GPU expensive, since we don't accumulate the results in the GPU,
#   at the expense of more system RAM usage).
#   This option runs out of memory in Google Colab with the standard CPU runtime
#
# We take option (b)
# Note: we don't need to preallocate the tensor, but it's more memory-efficient

#  We can also reduce the memory footprint of the last two options
#  with dtype=torch.bfloat16 or torch.float16
dtype = torch.float32

# Preallocate output tensor
y_hat = torch.full(
    (len(x), QUANTILES.size, *tiler.tile_size),
    torch.nan,
    dtype=dtype,
    device=torch.device('cuda')
)

bs = 1 # batch size -- higher values can be used
for i in tqdm.tqdm(range(0, len(x), bs), desc="Inference"):
    y_hat[i:(i+bs)] = model_gpu(x[i:(i+bs)].cuda()).to(dtype)

times['retrieval_gpu'] = time.time() - t

# %%
# Assemble the tiles
t = time.time()
y_hat = y_hat.view(tiler.M, tiler.N, 1, *y_hat.shape[1:])
y_hat = tiler.assemble(y_hat)
times['assembly'] = time.time() - t

# update dtype if necessary for the next steps:
if y_hat.dtype != torch.float32:
    y_hat = y_hat.to(torch.float32)

# and place y_hat in CPU
y_hat = y_hat.cpu().numpy()

# %%
# ====================
# Compute statistics
t = time.time()
# The expected value
# As the inference step, we process the retrievals in batches
# (10 batches) due to the available resources in this runtime
spatial_shape = y_hat.shape[-2:]
y_hat = y_hat.reshape(1, QUANTILES.size, -1)
y_mu = np.concatenate(
    [
        quantnn.quantiles.posterior_mean(
            _y_hat,
            QUANTILES.astype('float32'),
            quantile_axis=1
        )
        for _y_hat in np.array_split(y_hat, 10, axis=-1)
    ],
    axis=-1
).reshape(1, *spatial_shape)
times['statistic (mu)'] = time.time() - t

# %%
# And quantiles at level tau = 16% and 84%
# we could use quantnn.quantiles.posterior_quantiles,
# but these quantile levels are directly given by the RoA network
t = time.time()
tau = np.array([0.16, 0.84])
y_tau = y_hat[:, np.isin(QUANTILES, tau)].reshape(1, tau.size, *spatial_shape)
times['statistic (quantiles)'] = time.time() - t

# %%
# ====================
# Create an xarray.Dataset with the statistic computed
t = time.time()
ds_out = xr.Dataset(
    data_vars={
        "hat_y_mu": (["nat_file", "y", "x"], y_mu),
        "hat_y_tau": (["nat_file", "tau", "y", "x"], y_tau)
    },
    coords={
        "x": ds.x.data,
        "y": ds.y.data,
        "nat_file": [entry],
        "tau": tau,
    }
)

# and "save" it, just as an example
# Clear attributes that are not serializable
for v in ds_out:
    ds_out[v].attrs = {}
ds_out.to_netcdf(opath / f'{entry}.nc') # .to_zarr(opath / f'{entry}.zrr') for cloud-optimized
times['save'] = time.time() - t

# %% [markdown]
# Show how long it took each step:

# %%
for k, v in times.items():
    print(f'{k}: {v:.2f} [s]')

# %% [markdown]
# Let's visualize the input and the retrieved $\hat{y}_{\mu}$, $\hat{y}_{16\%}$, and $\hat{y}_{84\%}$:

# %%
crs = SEVIRI_0DEG_AREADEF.to_cartopy_crs()
fig, axs = plt.subplots(ncols=4, nrows=3, subplot_kw={'projection': crs}, figsize=(20, 15))

ax = axs.ravel()[0]
ax.set_axis_off()
instrument, timestamp = ds_out.nat_file.data.item().replace('.nat','').split('-NA-')
ax.text(
    0.5, 0.5,
    f'Platform: {instrument}\nTimestamp: {timestamp.split(".")[0]}',
    ha='center',
    va='center',
    transform=ax.transAxes,
    bbox={'facecolor': 'grey', 'alpha': 0.5, 'pad': 10},
    fontweight='bold'
)

kwargs_bts = {'transform': crs, 'cmap': cmocean.cm.thermal}
for i, k in enumerate(list(ds)[:7], start=1):
    ax = axs.ravel()[i]
    x, y = np.broadcast_arrays(ds.x.data[None, :], ds.y.data[:, None])
    m = ax.pcolormesh(x, y, ds[k].sel(nat_file=entry).data, **kwargs_bts)
    ax.coastlines()
    ax.gridlines()
    fig.colorbar(m, ax=ax, label=ds[k].units)
    ax.set_title(k)

ax = axs.ravel()[-4]
ax.set_axis_off()
instrument, timestamp = ds_out.nat_file.data.item().replace('.nat','').split('-NA-')
ax.text(
    0.5, 0.5,
    'RoA retrievals',
    ha='center',
    va='center',
    transform=ax.transAxes,
    bbox={'facecolor': 'grey', 'alpha': 0.5, 'pad': 10},
    fontweight='bold'
)

kwargs_roa = {
    'transform': crs,
    'norm': matplotlib.colors.LogNorm(vmin=0.2, vmax=50),
    'cmap': cmocean.cm.rain
}

ax = axs.ravel()[-3]
x, y = np.broadcast_arrays(ds_out.x.data[None, :], ds_out.y.data[:, None])
m = ax.pcolormesh(x, y, ds_out.hat_y_mu.sel(nat_file=entry).data, **kwargs_roa)
m.cmap.set_under('white')
m.cmap.set_over('black')
ax.coastlines()
ax.gridlines(draw_labels=True)
fig.colorbar(m, ax=ax, label='Rain rate [mm/h]', extend='both')
ax.set_title(r'$\hat{y}_{\mu}$')

for i, t in enumerate(tau):
  ax = axs.ravel()[-2 + i]
  x, y = np.broadcast_arrays(ds_out.x.data[None, :], ds_out.y.data[:, None])
  m = ax.pcolormesh(x, y, ds_out.hat_y_tau.sel(nat_file=entry, tau=t).data, **kwargs_roa)
  m.cmap.set_under('white')
  m.cmap.set_over('black')
  ax.coastlines()
  ax.gridlines(draw_labels=True)
  fig.colorbar(m, ax=ax, label='Rain rate [mm/h]', extend='both')
  ax.set_title(rf'$\hat{{y}}_{{{int(t*100)}\%}}$')

plt.show()
